# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df=np.loadtxt("Derivada.dat", delimiter=",")

# %%
t=df[:,0]
x=df[:,1]

# %%
plt.plot(t,x, label="Derivada")
plt.title("Derivada central con Δt=0.01")
# Out:
# Text(0.5, 1.0, 'Derivada central con Δt=0.01')
